# %%
import pandas as pd
import numpy as np

#  plot confusion matrices
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing

import sys
sys.path.insert(1, '../../')
from py_oqat.config_algorithms import ACOConfig
from py_oqat.classifier import OQATClassifier

# %%
# Load iris dataset from sklearn
df = pd.read_csv('../../datasets/hayes_roth.csv')
# df = pd.read_csv('datasets/car.csv')


# Separate features and labels into two dataframes
X = df.drop('class', axis=1)
y = df['class']

# Define the feature type for each column (discrete or continuous)
column_names = X.columns.to_list()
column_types = ['cat', 'cat', 'cat', 'cat']

# transform the dataframes into a numpy array
X = X.values
y = y.values

X = preprocessing.OrdinalEncoder().fit_transform(X)
y = preprocessing.LabelEncoder().fit_transform(y)

print(X.shape)
print(y.shape)
# Out:
# (132, 4)
# (132,)

# %%
# Hypothesis: OQAT outperforms decision trees on small datasets

SEED = 42

training_sizes = [i / 100 for i in range(15, 95, 5)]
print(training_sizes)

runs = 10
decision_tree_models = []
oqat_models = []

decision_tree_runs = []
oqat_runs_bs_w = []
oqat_runs_bs_wn = []
oqat_runs_bs_d = []
oqat_runs_d_w = []
oqat_runs_d_wn = []
oqat_runs_d_d = []
for run in range(runs):
    decision_tree_results = []
    oqat_results_bs_w = []
    oqat_results_bs_wn = []
    oqat_results_bs_d = []
    oqat_results_d_w = []
    oqat_results_d_wn = []
    oqat_results_d_d = []


    for train_size in training_sizes:
        print(f"===== train size {train_size} ====")
        # Split the data into training and testing sets
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1-train_size, random_state=SEED+run)
        
        print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
        print("Distribution of training data")
        print(pd.Series(y_train).value_counts())

        # Train a decision tree classifier
        tree_model = DecisionTreeClassifier()
        tree_model.fit(X_train, y_train)
        y_pred_tree = tree_model.predict(X_test)
        cm_tree = confusion_matrix(y_test, y_pred_tree)
        tree_score = tree_model.score(X_test, y_test)
        print("Score decision tree: ", tree_score)
        decision_tree_results.append(tree_score)
        
        # Training data distribution with oqat
        aco_config = ACOConfig(algorithm="vertex-ac", cycles=20, ants=10, alpha=1, rho=0.99, tau_max=6., tau_min=0.01)
        classifier = OQATClassifier(collision_strategy="best_score", null_strategy="weighted", heuristic="aco", heuristic_config=aco_config)
        classifier.fit(X_train, y_train, column_names, column_types, n_discrete_bins=3)

        classifier.collision_strategy = "best_score"
        classifier.null_strategy = "weighted"
        y_pred_bs_w = classifier.predict(X_test, column_names)
        bs_w_score = classifier.score(y_pred_bs_w, y_test)
        print("Score oqat_bs_w: ", bs_w_score)
        oqat_results_bs_w.append(bs_w_score)

        classifier.collision_strategy = "best_score"
        classifier.null_strategy = "weighted_normalized"
        y_pred_bs_wn = classifier.predict(X_test, column_names)
        bs_wn_score = classifier.score(y_pred_bs_wn, y_test)
        print("Score oqat_bs_wn: ", bs_wn_score)
        oqat_results_bs_wn.append(bs_wn_score)

        classifier.collision_strategy = "best_score"
        classifier.null_strategy = "dissimilarity"
        y_pred_bs_d = classifier.predict(X_test, column_names)
        bs_d_score = classifier.score(y_pred_bs_d, y_test)
        print("Score oqat_bs_d: ", bs_d_score)
        oqat_results_bs_d.append(bs_d_score)

        classifier.collision_strategy = "dissimilarity"
        classifier.null_strategy = "weighted"
        y_pred_d_w = classifier.predict(X_test, column_names)
        d_w_score = classifier.score(y_pred_d_w, y_test)
        print("Score oqat_d_w: ", d_w_score)
        oqat_results_d_w.append(d_w_score)

        classifier.collision_strategy = "dissimilarity"
        classifier.null_strategy = "weighted_normalized"
        y_pred_d_wn = classifier.predict(X_test, column_names)
        d_wn_score = classifier.score(y_pred_d_wn, y_test)
        print("Score oqat_d_wn: ", d_wn_score)
        oqat_results_d_wn.append(d_wn_score)

        classifier.collision_strategy = "dissimilarity"
        classifier.null_strategy = "dissimilarity"
        y_pred_d_d = classifier.predict(X_test, column_names)
        d_d_score = classifier.score(y_pred_d_d, y_test)
        print("Score oqat_d_d: ", d_d_score)
        oqat_results_d_d.append(d_d_score)

    decision_tree_runs.append(decision_tree_results)
    oqat_runs_bs_w.append(oqat_results_bs_w)
    oqat_runs_bs_wn.append(oqat_results_bs_wn)
    oqat_runs_bs_d.append(oqat_results_bs_d)
    oqat_runs_d_w.append(oqat_results_d_w)
    oqat_runs_d_wn.append(oqat_results_d_wn)
    oqat_runs_d_d.append(oqat_results_d_d)

    decision_tree_models.append(tree_model)
    oqat_models.append(classifier)
# Out:
# [0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
# ===== train size 0.15 ====
# (19, 4) (19,) (113, 4) (113,)
# Distribution of training data
# 1    9
# 2    6
# 0    4
# dtype: int64
# Score decision tree:  0.584070796460177
# Score oqat_bs_w:  0.5398230088495575
# Score oqat_bs_wn:  0.5398230088495575
# Score oqat_bs_d:  0.5398230088495575
# Score oqat_d_w:  0.45132743362831856
# Score oqat_d_wn:  0.45132743362831856
# Score oqat_d_d:  0.45132743362831856
# ===== train size 0.2 ====
# (26, 4) (26,) (106, 4) (106,)
# Distribution of training data
# 1    13
# 2     7
# 0     6
# dtype: int64
# Score decision tree:  0.5283018867924528
# Score oqat_bs_w:  0.6509433962264151
# Score oqat_bs_wn:  0.5943396226415094
# Score oqat_bs_d:  0.6226415094339622
# Score oqat_d_w:  0.5754716981132075
# Score oqat_d_wn:  0.5188679245283019
# Score oqat_d_d:  0.5471698113207547
# ===== train size 0.25 ====
# (33, 4) (33,) (99, 4) (99,)
# Distribution of training data
# 1    15
# 0    10
# 2     8
# dtype: int64
# Score decision tree:  0.7878787878787878
# Score oqat_bs_w:  0.7070707070707071
# Score oqat_bs_wn:  0.7070707070707071
# Score oqat_bs_d:  0.7070707070707071
# Score oqat_d_w:  0.5959595959595959
# Score oqat_d_wn:  0.5959595959595959
# Score oqat_d_d:  0.5959595959595959
# ===== train size 0.3 ====
# (39, 4) (39,) (93, 4) (93,)
# Distribution of training data
# 1    18
# 0    13
# 2     8
# dtype: int64
# Score decision tree:  0.7956989247311828
# Score oqat_bs_w:  0.6774193548387096
# Score oqat_bs_wn:  0.6774193548387096
# Score oqat_bs_d:  0.6881720430107527
# Score oqat_d_w:  0.6559139784946236
# Score oqat_d_wn:  0.6559139784946236
# Score oqat_d_d:  0.6666666666666666
# ===== train size 0.35 ====
# (46, 4) (46,) (86, 4) (86,)
# Distribution of training data
# 1    21
# 0    16
# 2     9
# dtype: int64
# Score decision tree:  0.8488372093023255
# Score oqat_bs_w:  0.7790697674418605
# Score oqat_bs_wn:  0.7790697674418605
# Score oqat_bs_d:  0.7790697674418605
# Score oqat_d_w:  0.6162790697674418
# Score oqat_d_wn:  0.6162790697674418
# Score oqat_d_d:  0.6162790697674418
# ===== train size 0.4 ====
# (52, 4) (52,) (80, 4) (80,)
# Distribution of training data
# 1    21
# 0    20
# 2    11
# dtype: int64
# Score decision tree:  0.8125
# Score oqat_bs_w:  0.7
# Score oqat_bs_wn:  0.725
# Score oqat_bs_d:  0.725
# Score oqat_d_w:  0.65
# Score oqat_d_wn:  0.675
# Score oqat_d_d:  0.675
# ===== train size 0.45 ====
# (59, 4) (59,) (73, 4) (73,)
# Distribution of training data
# 1    25
# 0    22
# 2    12
# dtype: int64
# Score decision tree:  0.821917808219178
# Score oqat_bs_w:  0.7534246575342466
# Score oqat_bs_wn:  0.7534246575342466
# Score oqat_bs_d:  0.7397260273972602
# Score oqat_d_w:  0.6712328767123288
# Score oqat_d_wn:  0.6712328767123288
# Score oqat_d_d:  0.6575342465753424
# ===== train size 0.5 ====
# (66, 4) (66,) (66, 4) (66,)
# Distribution of training data
# 1    28
# 0    25
# 2    13
# dtype: int64
# Score decision tree:  0.8181818181818182
# Score oqat_bs_w:  0.6515151515151515
# Score oqat_bs_wn:  0.6515151515151515
# Score oqat_bs_d:  0.6060606060606061
# Score oqat_d_w:  0.6515151515151515
# Score oqat_d_wn:  0.6515151515151515
# Score oqat_d_d:  0.6060606060606061
# ===== train size 0.55 ====
# (72, 4) (72,) (60, 4) (60,)
# Distribution of training data
# 1    30
# 0    26
# 2    16
# dtype: int64
# Score decision tree:  0.85
# Score oqat_bs_w:  0.7666666666666667
# Score oqat_bs_wn:  0.7666666666666667
# Score oqat_bs_d:  0.7666666666666667
# Score oqat_d_w:  0.7
# Score oqat_d_wn:  0.7
# Score oqat_d_d:  0.7
# ===== train size 0.6 ====
# (79, 4) (79,) (53, 4) (53,)
# Distribution of training data
# 1    33
# 0    28
# 2    18
# dtype: int64
# Score decision tree:  0.8113207547169812
# Score oqat_bs_w:  0.8113207547169812
# Score oqat_bs_wn:  0.7924528301886793
# Score oqat_bs_d:  0.7735849056603774
# Score oqat_d_w:  0.8113207547169812
# Score oqat_d_wn:  0.7924528301886793
# Score oqat_d_d:  0.7735849056603774
# ===== train size 0.65 ====
# (85, 4) (85,) (47, 4) (47,)
# Distribution of training data
# 1    36
# 0    31
# 2    18
# dtype: int64
# Score decision tree:  0.8297872340425532
# Score oqat_bs_w:  0.7872340425531915
# Score oqat_bs_wn:  0.7872340425531915
# Score oqat_bs_d:  0.7659574468085106
# Score oqat_d_w:  0.6808510638297872
# Score oqat_d_wn:  0.6808510638297872
# Score oqat_d_d:  0.6595744680851063
# ===== train size 0.7 ====
# (92, 4) (92,) (40, 4) (40,)
# Distribution of training data
# 1    41
# 0    32
# 2    19
# dtype: int64
# Score decision tree:  0.825
# Score oqat_bs_w:  0.675
# Score oqat_bs_wn:  0.675
# Score oqat_bs_d:  0.675
# Score oqat_d_w:  0.65
# Score oqat_d_wn:  0.65
# Score oqat_d_d:  0.65
# ===== train size 0.75 ====
# (99, 4) (99,) (33, 4) (33,)
# Distribution of training data
# 1    42
# 0    36
# 2    21
# dtype: int64
# Score decision tree:  0.7878787878787878
# Score oqat_bs_w:  0.7878787878787878
# Score oqat_bs_wn:  0.7878787878787878
# Score oqat_bs_d:  0.7878787878787878
# Score oqat_d_w:  0.7878787878787878
# Score oqat_d_wn:  0.7878787878787878
# Score oqat_d_d:  0.7878787878787878
# ===== train size 0.8 ====
# (105, 4) (105,) (27, 4) (27,)
# Distribution of training data
# 1    43
# 0    39
# 2    23
# dtype: int64
# Score decision tree:  0.7777777777777778
# Score oqat_bs_w:  0.8148148148148148
# Score oqat_bs_wn:  0.7777777777777778
# Score oqat_bs_d:  0.7777777777777778
# Score oqat_d_w:  0.6666666666666666
# Score oqat_d_wn:  0.6296296296296297
# Score oqat_d_d:  0.6296296296296297
# ===== train size 0.85 ====
# (112, 4) (112,) (20, 4) (20,)
# Distribution of training data
# 1    44
# 0    42
# 2    26
# dtype: int64
# Score decision tree:  0.85
# Score oqat_bs_w:  0.8
# Score oqat_bs_wn:  0.8
# Score oqat_bs_d:  0.75
# Score oqat_d_w:  0.85
# Score oqat_d_wn:  0.85
# Score oqat_d_d:  0.8
# ===== train size 0.9 ====
# (118, 4) (118,) (14, 4) (14,)
# Distribution of training data
# 1    47
# 0    43
# 2    28
# dtype: int64
# Score decision tree:  0.7142857142857143
# Score oqat_bs_w:  0.6428571428571429
# Score oqat_bs_wn:  0.6428571428571429
# Score oqat_bs_d:  0.6428571428571429
# Score oqat_d_w:  0.7142857142857143
# Score oqat_d_wn:  0.7142857142857143
# Score oqat_d_d:  0.7142857142857143
# ===== train size 0.15 ====
# (19, 4) (19,) (113, 4) (113,)
# Distribution of training data
# 1    9
# 0    6
# 2    4
# dtype: int64
# Score decision tree:  0.5309734513274337
# Score oqat_bs_w:  0.6371681415929203
# Score oqat_bs_wn:  0.6371681415929203
# Score oqat_bs_d:  0.6371681415929203
# Score oqat_d_w:  0.5398230088495575
# Score oqat_d_wn:  0.5398230088495575
# Score oqat_d_d:  0.5398230088495575
# ===== train size 0.2 ====
# (26, 4) (26,) (106, 4) (106,)
# Distribution of training data
# 1    11
# 0     8
# 2     7
# dtype: int64
# Score decision tree:  0.6698113207547169
# Score oqat_bs_w:  0.6226415094339622
# Score oqat_bs_wn:  0.5849056603773585
# Score oqat_bs_d:  0.6226415094339622
# Score oqat_d_w:  0.5754716981132075
# Score oqat_d_wn:  0.5377358490566038
# Score oqat_d_d:  0.5754716981132075
# ===== train size 0.25 ====
# (33, 4) (33,) (99, 4) (99,)
# Distribution of training data
# 1    13
# 0    11
# 2     9
# dtype: int64
# Score decision tree:  0.7575757575757576
# Score oqat_bs_w:  0.7070707070707071
# Score oqat_bs_wn:  0.7070707070707071
# Score oqat_bs_d:  0.6868686868686869
# Score oqat_d_w:  0.6868686868686869
# Score oqat_d_wn:  0.6868686868686869
# Score oqat_d_d:  0.6666666666666666
# ===== train size 0.3 ====
# (39, 4) (39,) (93, 4) (93,)
# Distribution of training data
# 1    16
# 0    14
# 2     9
# dtype: int64
# Score decision tree:  0.8064516129032258
# Score oqat_bs_w:  0.6989247311827957
# Score oqat_bs_wn:  0.6989247311827957
# Score oqat_bs_d:  0.6666666666666666
# Score oqat_d_w:  0.6559139784946236
# Score oqat_d_wn:  0.6559139784946236
# Score oqat_d_d:  0.6236559139784946
# ===== train size 0.35 ====
# (46, 4) (46,) (86, 4) (86,)
# Distribution of training data
# 1    18
# 0    16
# 2    12
# dtype: int64
# Score decision tree:  0.7674418604651163
# Score oqat_bs_w:  0.8023255813953488
# Score oqat_bs_wn:  0.8023255813953488
# Score oqat_bs_d:  0.8023255813953488
# Score oqat_d_w:  0.7790697674418605
# Score oqat_d_wn:  0.7790697674418605
# Score oqat_d_d:  0.7790697674418605
# ===== train size 0.4 ====
# (52, 4) (52,) (80, 4) (80,)
# Distribution of training data
# 1    21
# 0    18
# 2    13
# dtype: int64
# Score decision tree:  0.7375
# Score oqat_bs_w:  0.7625
# Score oqat_bs_wn:  0.7625
# Score oqat_bs_d:  0.7625
# Score oqat_d_w:  0.7
# Score oqat_d_wn:  0.7
# Score oqat_d_d:  0.7
# ===== train size 0.45 ====
# (59, 4) (59,) (73, 4) (73,)
# Distribution of training data
# 1    26
# 0    19
# 2    14
# dtype: int64
# Score decision tree:  0.8356164383561644
# Score oqat_bs_w:  0.7534246575342466
# Score oqat_bs_wn:  0.7534246575342466
# Score oqat_bs_d:  0.7534246575342466
# Score oqat_d_w:  0.6712328767123288
# Score oqat_d_wn:  0.6712328767123288
# Score oqat_d_d:  0.6712328767123288
# ===== train size 0.5 ====
# (66, 4) (66,) (66, 4) (66,)
# Distribution of training data
# 1    28
# 0    24
# 2    14
# dtype: int64
# Score decision tree:  0.803030303030303
# Score oqat_bs_w:  0.7878787878787878
# Score oqat_bs_wn:  0.7878787878787878
# Score oqat_bs_d:  0.803030303030303
# Score oqat_d_w:  0.7424242424242424
# Score oqat_d_wn:  0.7424242424242424
# Score oqat_d_d:  0.7575757575757576
# ===== train size 0.55 ====
# (72, 4) (72,) (60, 4) (60,)
# Distribution of training data
# 1    32
# 0    26
# 2    14
# dtype: int64
# Score decision tree:  0.85
# Score oqat_bs_w:  0.7666666666666667
# Score oqat_bs_wn:  0.7666666666666667
# Score oqat_bs_d:  0.75
# Score oqat_d_w:  0.7333333333333333
# Score oqat_d_wn:  0.7333333333333333
# Score oqat_d_d:  0.7166666666666667
# ===== train size 0.6 ====
# (79, 4) (79,) (53, 4) (53,)
# Distribution of training data
# 1    35
# 0    29
# 2    15
# dtype: int64
# Score decision tree:  0.8301886792452831
# Score oqat_bs_w:  0.7735849056603774
# Score oqat_bs_wn:  0.7735849056603774
# Score oqat_bs_d:  0.7924528301886793
# Score oqat_d_w:  0.7358490566037735
# Score oqat_d_wn:  0.7358490566037735
# Score oqat_d_d:  0.7547169811320755
# ===== train size 0.65 ====
# (85, 4) (85,) (47, 4) (47,)
# Distribution of training data
# 1    37
# 0    31
# 2    17
# dtype: int64
# Score decision tree:  0.8723404255319149
# Score oqat_bs_w:  0.851063829787234
# Score oqat_bs_wn:  0.851063829787234
# Score oqat_bs_d:  0.8297872340425532
# Score oqat_d_w:  0.8297872340425532
# Score oqat_d_wn:  0.8297872340425532
# Score oqat_d_d:  0.8085106382978723
# ===== train size 0.7 ====
# (92, 4) (92,) (40, 4) (40,)
# Distribution of training data
# 1    38
# 0    35
# 2    19
# dtype: int64
# Score decision tree:  0.85
# Score oqat_bs_w:  0.85
# Score oqat_bs_wn:  0.85
# Score oqat_bs_d:  0.85
# Score oqat_d_w:  0.75
# Score oqat_d_wn:  0.75
# Score oqat_d_d:  0.75
# ===== train size 0.75 ====
# (99, 4) (99,) (33, 4) (33,)
# Distribution of training data
# 1    41
# 0    39
# 2    19
# dtype: int64
# Score decision tree:  0.8181818181818182
# Score oqat_bs_w:  0.8484848484848485
# Score oqat_bs_wn:  0.8484848484848485
# Score oqat_bs_d:  0.8484848484848485
# Score oqat_d_w:  0.7878787878787878
# Score oqat_d_wn:  0.7878787878787878
# Score oqat_d_d:  0.7878787878787878
# ===== train size 0.8 ====
# (105, 4) (105,) (27, 4) (27,)
# Distribution of training data
# 1    42
# 0    42
# 2    21
# dtype: int64
# Score decision tree:  0.8518518518518519
# Score oqat_bs_w:  0.7777777777777778
# Score oqat_bs_wn:  0.7777777777777778
# Score oqat_bs_d:  0.7777777777777778
# Score oqat_d_w:  0.6666666666666666
# Score oqat_d_wn:  0.6666666666666666
# Score oqat_d_d:  0.6666666666666666
# ===== train size 0.85 ====
# (112, 4) (112,) (20, 4) (20,)
# Distribution of training data
# 0    46
# 1    44
# 2    22
# dtype: int64
# Score decision tree:  0.8
# Score oqat_bs_w:  0.8
# Score oqat_bs_wn:  0.8
# Score oqat_bs_d:  0.8
# Score oqat_d_w:  0.75
# Score oqat_d_wn:  0.75
# Score oqat_d_d:  0.75
# ===== train size 0.9 ====
# (118, 4) (118,) (14, 4) (14,)
# Distribution of training data
# 0    48
# 1    47
# 2    23
# dtype: int64
# Score decision tree:  0.8571428571428571
# Score oqat_bs_w:  0.8571428571428571
# Score oqat_bs_wn:  0.8571428571428571
# Score oqat_bs_d:  0.8571428571428571
# Score oqat_d_w:  0.7142857142857143
# Score oqat_d_wn:  0.7142857142857143
# Score oqat_d_d:  0.7142857142857143
# ===== train size 0.15 ====
# (19, 4) (19,) (113, 4) (113,)
# Distribution of training data
# 1    11
# 0     5
# 2     3
# dtype: int64
# Score decision tree:  0.6902654867256637
# Score oqat_bs_w:  0.5221238938053098
# Score oqat_bs_wn:  0.5221238938053098
# Score oqat_bs_d:  0.5221238938053098
# Score oqat_d_w:  0.504424778761062
# Score oqat_d_wn:  0.504424778761062
# Score oqat_d_d:  0.504424778761062
# ===== train size 0.2 ====
# (26, 4) (26,) (106, 4) (106,)
# Distribution of training data
# 1    15
# 0     7
# 2     4
# dtype: int64
# Score decision tree:  0.660377358490566
# Score oqat_bs_w:  0.6698113207547169
# Score oqat_bs_wn:  0.6698113207547169
# Score oqat_bs_d:  0.7169811320754716
# Score oqat_d_w:  0.5094339622641509
# Score oqat_d_wn:  0.5094339622641509
# Score oqat_d_d:  0.5566037735849056
# ===== train size 0.25 ====
# (33, 4) (33,) (99, 4) (99,)
# Distribution of training data
# 1    17
# 0    10
# 2     6
# dtype: int64
# Score decision tree:  0.5858585858585859
# Score oqat_bs_w:  0.6464646464646465
# Score oqat_bs_wn:  0.6464646464646465
# Score oqat_bs_d:  0.6666666666666666
# Score oqat_d_w:  0.494949494949495
# Score oqat_d_wn:  0.494949494949495
# Score oqat_d_d:  0.5151515151515151
# ===== train size 0.3 ====
# (39, 4) (39,) (93, 4) (93,)
# Distribution of training data
# 1    20
# 0    11
# 2     8
# dtype: int64
# Score decision tree:  0.6559139784946236
# Score oqat_bs_w:  0.6236559139784946
# Score oqat_bs_wn:  0.6236559139784946
# Score oqat_bs_d:  0.6236559139784946
# Score oqat_d_w:  0.6774193548387096
# Score oqat_d_wn:  0.6774193548387096
# Score oqat_d_d:  0.6774193548387096
# ===== train size 0.35 ====
# (46, 4) (46,) (86, 4) (86,)
# Distribution of training data
# 1    21
# 0    15
# 2    10
# dtype: int64
# Score decision tree:  0.8255813953488372
# Score oqat_bs_w:  0.6627906976744186
# Score oqat_bs_wn:  0.6627906976744186
# Score oqat_bs_d:  0.6627906976744186
# Score oqat_d_w:  0.6395348837209303
# Score oqat_d_wn:  0.6395348837209303
# Score oqat_d_d:  0.6395348837209303
# ===== train size 0.4 ====
# (52, 4) (52,) (80, 4) (80,)
# Distribution of training data
# 1    23
# 0    17
# 2    12
# dtype: int64
# Score decision tree:  0.8375
# Score oqat_bs_w:  0.7
# Score oqat_bs_wn:  0.6375
# Score oqat_bs_d:  0.6375
# Score oqat_d_w:  0.6375
# Score oqat_d_wn:  0.575
# Score oqat_d_d:  0.575
# ===== train size 0.45 ====
# (59, 4) (59,) (73, 4) (73,)
# Distribution of training data
# 1    24
# 0    20
# 2    15
# dtype: int64
# Score decision tree:  0.821917808219178
# Score oqat_bs_w:  0.7397260273972602
# Score oqat_bs_wn:  0.7397260273972602
# Score oqat_bs_d:  0.7671232876712328
# Score oqat_d_w:  0.6164383561643836
# Score oqat_d_wn:  0.6164383561643836
# Score oqat_d_d:  0.6438356164383562
# ===== train size 0.5 ====
# (66, 4) (66,) (66, 4) (66,)
# Distribution of training data
# 1    26
# 0    25
# 2    15
# dtype: int64
# Score decision tree:  0.7575757575757576
# Score oqat_bs_w:  0.8181818181818182
# Score oqat_bs_wn:  0.8181818181818182
# Score oqat_bs_d:  0.8333333333333334
# Score oqat_d_w:  0.6818181818181818
# Score oqat_d_wn:  0.6818181818181818
# Score oqat_d_d:  0.696969696969697
# ===== train size 0.55 ====
# (72, 4) (72,) (60, 4) (60,)
# Distribution of training data
# 1    30
# 0    27
# 2    15
# dtype: int64
# Score decision tree:  0.8333333333333334
# Score oqat_bs_w:  0.7
# Score oqat_bs_wn:  0.7
# Score oqat_bs_d:  0.7
# Score oqat_d_w:  0.65
# Score oqat_d_wn:  0.65
# Score oqat_d_d:  0.65
# ===== train size 0.6 ====
# (79, 4) (79,) (53, 4) (53,)
# Distribution of training data
# 1    33
# 0    28
# 2    18
# dtype: int64
# Score decision tree:  0.8490566037735849
# Score oqat_bs_w:  0.8679245283018868
# Score oqat_bs_wn:  0.8679245283018868
# Score oqat_bs_d:  0.8490566037735849
# Score oqat_d_w:  0.7924528301886793
# Score oqat_d_wn:  0.7924528301886793
# Score oqat_d_d:  0.7735849056603774
# ===== train size 0.65 ====
# (85, 4) (85,) (47, 4) (47,)
# Distribution of training data
# 1    35
# 0    30
# 2    20
# dtype: int64
# Score decision tree:  0.8297872340425532
# Score oqat_bs_w:  0.8085106382978723
# Score oqat_bs_wn:  0.8085106382978723
# Score oqat_bs_d:  0.8085106382978723
# Score oqat_d_w:  0.6595744680851063
# Score oqat_d_wn:  0.6595744680851063
# Score oqat_d_d:  0.6595744680851063
# ===== train size 0.7 ====
# (92, 4) (92,) (40, 4) (40,)
# Distribution of training data
# 1    39
# 0    30
# 2    23
# dtype: int64
# Score decision tree:  0.75
# Score oqat_bs_w:  0.775
# Score oqat_bs_wn:  0.8
# Score oqat_bs_d:  0.775
# Score oqat_d_w:  0.75
# Score oqat_d_wn:  0.775
# Score oqat_d_d:  0.75
# ===== train size 0.75 ====
# (99, 4) (99,) (33, 4) (33,)
# Distribution of training data
# 1    41
# 0    35
# 2    23
# dtype: int64
# Score decision tree:  0.7878787878787878
# Score oqat_bs_w:  0.7878787878787878
# Score oqat_bs_wn:  0.7575757575757576
# Score oqat_bs_d:  0.8181818181818182
# Score oqat_d_w:  0.696969696969697
# Score oqat_d_wn:  0.6666666666666666
# Score oqat_d_d:  0.7272727272727273
# ===== train size 0.8 ====
# (105, 4) (105,) (27, 4) (27,)
# Distribution of training data
# 1    43
# 0    39
# 2    23
# dtype: int64
# Score decision tree:  0.7407407407407407
# Score oqat_bs_w:  0.8148148148148148
# Score oqat_bs_wn:  0.7777777777777778
# Score oqat_bs_d:  0.7777777777777778
# Score oqat_d_w:  0.7037037037037037
# Score oqat_d_wn:  0.6666666666666666
# Score oqat_d_d:  0.6666666666666666
# ===== train size 0.85 ====
# (112, 4) (112,) (20, 4) (20,)
# Distribution of training data
# 1    44
# 0    41
# 2    27
# dtype: int64
# Score decision tree:  0.7
# Score oqat_bs_w:  0.75
# Score oqat_bs_wn:  0.75
# Score oqat_bs_d:  0.75
# Score oqat_d_w:  0.65
# Score oqat_d_wn:  0.65
# Score oqat_d_d:  0.65
# ===== train size 0.9 ====
# (118, 4) (118,) (14, 4) (14,)
# Distribution of training data
# 1    47
# 0    44
# 2    27
# dtype: int64
# Score decision tree:  0.7142857142857143
# Score oqat_bs_w:  0.7857142857142857
# Score oqat_bs_wn:  0.7857142857142857
# Score oqat_bs_d:  0.7142857142857143
# Score oqat_d_w:  0.7857142857142857
# Score oqat_d_wn:  0.7857142857142857
# Score oqat_d_d:  0.7142857142857143
# ===== train size 0.15 ====
# (19, 4) (19,) (113, 4) (113,)
# Distribution of training data
# 0    8
# 1    8
# 2    3
# dtype: int64
# Score decision tree:  0.5929203539823009
# Score oqat_bs_w:  0.5929203539823009
# Score oqat_bs_wn:  0.5929203539823009
# Score oqat_bs_d:  0.5929203539823009
# Score oqat_d_w:  0.5221238938053098
# Score oqat_d_wn:  0.5221238938053098
# Score oqat_d_d:  0.5221238938053098
# ===== train size 0.2 ====
# (26, 4) (26,) (106, 4) (106,)
# Distribution of training data
# 1    11
# 0    11
# 2     4
# dtype: int64
# Score decision tree:  0.6981132075471698
# Score oqat_bs_w:  0.6509433962264151
# Score oqat_bs_wn:  0.6509433962264151
# Score oqat_bs_d:  0.6509433962264151
# Score oqat_d_w:  0.6132075471698113
# Score oqat_d_wn:  0.6132075471698113
# Score oqat_d_d:  0.6132075471698113
# ===== train size 0.25 ====
# (33, 4) (33,) (99, 4) (99,)
# Distribution of training data
# 1    15
# 0    12
# 2     6
# dtype: int64
# Score decision tree:  0.8080808080808081
# Score oqat_bs_w:  0.7070707070707071
# Score oqat_bs_wn:  0.7070707070707071
# Score oqat_bs_d:  0.696969696969697
# Score oqat_d_w:  0.6262626262626263
# Score oqat_d_wn:  0.6262626262626263
# Score oqat_d_d:  0.6161616161616161
# ===== train size 0.3 ====
# (39, 4) (39,) (93, 4) (93,)
# Distribution of training data
# 1    17
# 0    14
# 2     8
# dtype: int64
# Score decision tree:  0.8064516129032258
# Score oqat_bs_w:  0.7311827956989247
# Score oqat_bs_wn:  0.7311827956989247
# Score oqat_bs_d:  0.7526881720430108
# Score oqat_d_w:  0.6559139784946236
# Score oqat_d_wn:  0.6559139784946236
# Score oqat_d_d:  0.6774193548387096
# ===== train size 0.35 ====
# (46, 4) (46,) (86, 4) (86,)
# Distribution of training data
# 1    18
# 0    17
# 2    11
# dtype: int64
# Score decision tree:  0.813953488372093
# Score oqat_bs_w:  0.7790697674418605
# Score oqat_bs_wn:  0.7790697674418605
# Score oqat_bs_d:  0.7790697674418605
# Score oqat_d_w:  0.7093023255813954
# Score oqat_d_wn:  0.7093023255813954
# Score oqat_d_d:  0.7093023255813954
# ===== train size 0.4 ====
# (52, 4) (52,) (80, 4) (80,)
# Distribution of training data
# 1    21
# 0    20
# 2    11
# dtype: int64
# Score decision tree:  0.8375
# Score oqat_bs_w:  0.75
# Score oqat_bs_wn:  0.75
# Score oqat_bs_d:  0.7375
# Score oqat_d_w:  0.7125
# Score oqat_d_wn:  0.7125
# Score oqat_d_d:  0.7
# ===== train size 0.45 ====
# (59, 4) (59,) (73, 4) (73,)
# Distribution of training data
# 1    23
# 0    22
# 2    14
# dtype: int64
# Score decision tree:  0.8356164383561644
# Score oqat_bs_w:  0.7397260273972602
# Score oqat_bs_wn:  0.7671232876712328
# Score oqat_bs_d:  0.7397260273972602
# Score oqat_d_w:  0.684931506849315
# Score oqat_d_wn:  0.7123287671232876
# Score oqat_d_d:  0.684931506849315
# ===== train size 0.5 ====
# (66, 4) (66,) (66, 4) (66,)
# Distribution of training data
# 1    26
# 0    25
# 2    15
# dtype: int64
# Score decision tree:  0.803030303030303
# Score oqat_bs_w:  0.6818181818181818
# Score oqat_bs_wn:  0.6818181818181818
# Score oqat_bs_d:  0.6818181818181818
# Score oqat_d_w:  0.7121212121212122
# Score oqat_d_wn:  0.7121212121212122
# Score oqat_d_d:  0.7121212121212122
# ===== train size 0.55 ====
# (72, 4) (72,) (60, 4) (60,)
# Distribution of training data
# 0    29
# 1    27
# 2    16
# dtype: int64
# Score decision tree:  0.8333333333333334
# Score oqat_bs_w:  0.8666666666666667
# Score oqat_bs_wn:  0.8666666666666667
# Score oqat_bs_d:  0.85
# Score oqat_d_w:  0.7333333333333333
# Score oqat_d_wn:  0.7333333333333333
# Score oqat_d_d:  0.7166666666666667
# ===== train size 0.6 ====
# (79, 4) (79,) (53, 4) (53,)
# Distribution of training data
# 0    33
# 1    29
# 2    17
# dtype: int64
# Score decision tree:  0.8301886792452831
# Score oqat_bs_w:  0.7547169811320755
# Score oqat_bs_wn:  0.7358490566037735
# Score oqat_bs_d:  0.8113207547169812
# Score oqat_d_w:  0.6792452830188679
# Score oqat_d_wn:  0.660377358490566
# Score oqat_d_d:  0.7358490566037735
# ===== train size 0.65 ====
# (85, 4) (85,) (47, 4) (47,)
# Distribution of training data
# 0    35
# 1    30
# 2    20
# dtype: int64
# Score decision tree:  0.851063829787234
# Score oqat_bs_w:  0.8297872340425532
# Score oqat_bs_wn:  0.8085106382978723
# Score oqat_bs_d:  0.8297872340425532
# Score oqat_d_w:  0.7659574468085106
# Score oqat_d_wn:  0.7446808510638298
# Score oqat_d_d:  0.7659574468085106
# ===== train size 0.7 ====
# (92, 4) (92,) (40, 4) (40,)
# Distribution of training data
# 0    36
# 1    34
# 2    22
# dtype: int64
# Score decision tree:  0.825
# Score oqat_bs_w:  0.8
# Score oqat_bs_wn:  0.8
# Score oqat_bs_d:  0.75
# Score oqat_d_w:  0.75
# Score oqat_d_wn:  0.75
# Score oqat_d_d:  0.7
# ===== train size 0.75 ====
# (99, 4) (99,) (33, 4) (33,)
# Distribution of training data
# 0    40
# 1    37
# 2    22
# dtype: int64
# Score decision tree:  0.7878787878787878
# Score oqat_bs_w:  0.7575757575757576
# Score oqat_bs_wn:  0.7575757575757576
# Score oqat_bs_d:  0.7272727272727273
# Score oqat_d_w:  0.696969696969697
# Score oqat_d_wn:  0.696969696969697
# Score oqat_d_d:  0.6666666666666666
# ===== train size 0.8 ====
# (105, 4) (105,) (27, 4) (27,)
# Distribution of training data
# 0    44
# 1    38
# 2    23
# dtype: int64
# Score decision tree:  0.7777777777777778
# Score oqat_bs_w:  0.8148148148148148
# Score oqat_bs_wn:  0.7777777777777778
# Score oqat_bs_d:  0.7777777777777778
# Score oqat_d_w:  0.7407407407407407
# Score oqat_d_wn:  0.7037037037037037
# Score oqat_d_d:  0.7037037037037037
# ===== train size 0.85 ====
# (112, 4) (112,) (20, 4) (20,)
# Distribution of training data
# 0    46
# 1    42
# 2    24
# dtype: int64
# Score decision tree:  0.75
# Score oqat_bs_w:  0.75
# Score oqat_bs_wn:  0.75
# Score oqat_bs_d:  0.85
# Score oqat_d_w:  0.6
# Score oqat_d_wn:  0.6
# Score oqat_d_d:  0.7
# ===== train size 0.9 ====
# (118, 4) (118,) (14, 4) (14,)
# Distribution of training data
# 0    48
# 1    44
# 2    26
# dtype: int64
# Score decision tree:  0.7857142857142857
# Score oqat_bs_w:  0.9285714285714286
# Score oqat_bs_wn:  0.9285714285714286
# Score oqat_bs_d:  0.7857142857142857
# Score oqat_d_w:  0.7857142857142857
# Score oqat_d_wn:  0.7857142857142857
# Score oqat_d_d:  0.6428571428571429
# ===== train size 0.15 ====
# (19, 4) (19,) (113, 4) (113,)
# Distribution of training data
# 1    8
# 2    7
# 0    4
# dtype: int64
# Score decision tree:  0.6371681415929203
# Score oqat_bs_w:  0.415929203539823
# Score oqat_bs_wn:  0.415929203539823
# Score oqat_bs_d:  0.415929203539823
# Score oqat_d_w:  0.504424778761062
# Score oqat_d_wn:  0.504424778761062
# Score oqat_d_d:  0.504424778761062
# ===== train size 0.2 ====
# (26, 4) (26,) (106, 4) (106,)
# Distribution of training data
# 1    13
# 2     8
# 0     5
# dtype: int64
# Score decision tree:  0.6226415094339622
# Score oqat_bs_w:  0.5849056603773585
# Score oqat_bs_wn:  0.5849056603773585
# Score oqat_bs_d:  0.5849056603773585
# Score oqat_d_w:  0.5566037735849056
# Score oqat_d_wn:  0.5566037735849056
# Score oqat_d_d:  0.5566037735849056
# ===== train size 0.25 ====
# (33, 4) (33,) (99, 4) (99,)
# Distribution of training data
# 1    15
# 0    10
# 2     8
# dtype: int64
# Score decision tree:  0.8585858585858586
# Score oqat_bs_w:  0.7373737373737373
# Score oqat_bs_wn:  0.7373737373737373
# Score oqat_bs_d:  0.7373737373737373
# Score oqat_d_w:  0.6161616161616161
# Score oqat_d_wn:  0.6161616161616161
# Score oqat_d_d:  0.6161616161616161
# ===== train size 0.3 ====
# (39, 4) (39,) (93, 4) (93,)
# Distribution of training data
# 1    19
# 0    12
# 2     8
# dtype: int64
# Score decision tree:  0.8279569892473119
# Score oqat_bs_w:  0.6559139784946236
# Score oqat_bs_wn:  0.6559139784946236
# Score oqat_bs_d:  0.6451612903225806
# Score oqat_d_w:  0.6451612903225806
# Score oqat_d_wn:  0.6451612903225806
# Score oqat_d_d:  0.6344086021505376
# ===== train size 0.35 ====
# (46, 4) (46,) (86, 4) (86,)
# Distribution of training data
# 1    22
# 0    14
# 2    10
# dtype: int64
# Score decision tree:  0.8488372093023255
# Score oqat_bs_w:  0.6744186046511628
# Score oqat_bs_wn:  0.6744186046511628
# Score oqat_bs_d:  0.6744186046511628
# Score oqat_d_w:  0.6976744186046512
# Score oqat_d_wn:  0.6976744186046512
# Score oqat_d_d:  0.6976744186046512
# ===== train size 0.4 ====
# (52, 4) (52,) (80, 4) (80,)
# Distribution of training data
# 1    23
# 0    19
# 2    10
# dtype: int64
# Score decision tree:  0.8625
# Score oqat_bs_w:  0.7375
# Score oqat_bs_wn:  0.7375
# Score oqat_bs_d:  0.75
# Score oqat_d_w:  0.75
# Score oqat_d_wn:  0.75
# Score oqat_d_d:  0.7625
# ===== train size 0.45 ====
# (59, 4) (59,) (73, 4) (73,)
# Distribution of training data
# 1    25
# 0    21
# 2    13
# dtype: int64
# Score decision tree:  0.863013698630137
# Score oqat_bs_w:  0.8082191780821918
# Score oqat_bs_wn:  0.8082191780821918
# Score oqat_bs_d:  0.821917808219178
# Score oqat_d_w:  0.821917808219178
# Score oqat_d_wn:  0.821917808219178
# Score oqat_d_d:  0.8356164383561644
# ===== train size 0.5 ====
# (66, 4) (66,) (66, 4) (66,)
# Distribution of training data
# 1    28
# 0    24
# 2    14
# dtype: int64
# Score decision tree:  0.8636363636363636
# Score oqat_bs_w:  0.8787878787878788
# Score oqat_bs_wn:  0.8636363636363636
# Score oqat_bs_d:  0.8636363636363636
# Score oqat_d_w:  0.8636363636363636
# Score oqat_d_wn:  0.8484848484848485
# Score oqat_d_d:  0.8484848484848485
# ===== train size 0.55 ====
# (72, 4) (72,) (60, 4) (60,)
# Distribution of training data
# 1    31
# 0    26
# 2    15
# dtype: int64
# Score decision tree:  0.8666666666666667
# Score oqat_bs_w:  0.7333333333333333
# Score oqat_bs_wn:  0.7333333333333333
# Score oqat_bs_d:  0.7666666666666667
# Score oqat_d_w:  0.7166666666666667
# Score oqat_d_wn:  0.7166666666666667
# Score oqat_d_d:  0.75
# ===== train size 0.6 ====
# (79, 4) (79,) (53, 4) (53,)
# Distribution of training data
# 1    34
# 0    27
# 2    18
# dtype: int64
# Score decision tree:  0.8867924528301887
# Score oqat_bs_w:  0.8867924528301887
# Score oqat_bs_wn:  0.8867924528301887
# Score oqat_bs_d:  0.8679245283018868
# Score oqat_d_w:  0.8301886792452831
# Score oqat_d_wn:  0.8301886792452831
# Score oqat_d_d:  0.8113207547169812
# ===== train size 0.65 ====
# (85, 4) (85,) (47, 4) (47,)
# Distribution of training data
# 1    35
# 0    31
# 2    19
# dtype: int64
# Score decision tree:  0.8723404255319149
# Score oqat_bs_w:  0.851063829787234
# Score oqat_bs_wn:  0.851063829787234
# Score oqat_bs_d:  0.851063829787234
# Score oqat_d_w:  0.8085106382978723
# Score oqat_d_wn:  0.8085106382978723
# Score oqat_d_d:  0.8085106382978723
# ===== train size 0.7 ====
# (92, 4) (92,) (40, 4) (40,)
# Distribution of training data
# 1    38
# 0    34
# 2    20
# dtype: int64
# Score decision tree:  0.875
# Score oqat_bs_w:  0.875
# Score oqat_bs_wn:  0.875
# Score oqat_bs_d:  0.875
# Score oqat_d_w:  0.875
# Score oqat_d_wn:  0.875
# Score oqat_d_d:  0.875
# ===== train size 0.75 ====
# (99, 4) (99,) (33, 4) (33,)
# Distribution of training data
# 1    40
# 0    38
# 2    21
# dtype: int64
# Score decision tree:  0.8484848484848485
# Score oqat_bs_w:  0.8484848484848485
# Score oqat_bs_wn:  0.8484848484848485
# Score oqat_bs_d:  0.8484848484848485
# Score oqat_d_w:  0.7575757575757576
# Score oqat_d_wn:  0.7575757575757576
# Score oqat_d_d:  0.7575757575757576
# ===== train size 0.8 ====
# (105, 4) (105,) (27, 4) (27,)
# Distribution of training data
# 1    42
# 0    40
# 2    23
# dtype: int64
# Score decision tree:  0.8518518518518519
# Score oqat_bs_w:  0.8148148148148148
# Score oqat_bs_wn:  0.7777777777777778
# Score oqat_bs_d:  0.7407407407407407
# Score oqat_d_w:  0.8518518518518519
# Score oqat_d_wn:  0.8148148148148148
# Score oqat_d_d:  0.7777777777777778
# ===== train size 0.85 ====
# (112, 4) (112,) (20, 4) (20,)
# Distribution of training data
# 1    44
# 0    42
# 2    26
# dtype: int64
# Score decision tree:  0.8
# Score oqat_bs_w:  0.8
# Score oqat_bs_wn:  0.8
# Score oqat_bs_d:  0.75
# Score oqat_d_w:  0.85
# Score oqat_d_wn:  0.85
# Score oqat_d_d:  0.8
# ===== train size 0.9 ====
# (118, 4) (118,) (14, 4) (14,)
# Distribution of training data
# 1    46
# 0    45
# 2    27
# dtype: int64
# Score decision tree:  0.9285714285714286
# Score oqat_bs_w:  0.7857142857142857
# Score oqat_bs_wn:  0.7857142857142857
# Score oqat_bs_d:  0.7857142857142857
# Score oqat_d_w:  0.8571428571428571
# Score oqat_d_wn:  0.8571428571428571
# Score oqat_d_d:  0.8571428571428571
# ===== train size 0.15 ====
# (19, 4) (19,) (113, 4) (113,)
# Distribution of training data
# 0    9
# 1    7
# 2    3
# dtype: int64
# Score decision tree:  0.584070796460177
# Score oqat_bs_w:  0.6194690265486725
# Score oqat_bs_wn:  0.6194690265486725
# Score oqat_bs_d:  0.6106194690265486
# Score oqat_d_w:  0.504424778761062
# Score oqat_d_wn:  0.504424778761062
# Score oqat_d_d:  0.49557522123893805
# ===== train size 0.2 ====
# (26, 4) (26,) (106, 4) (106,)
# Distribution of training data
# 0    11
# 1    11
# 2     4
# dtype: int64
# Score decision tree:  0.5188679245283019
# Score oqat_bs_w:  0.5943396226415094
# Score oqat_bs_wn:  0.5943396226415094
# Score oqat_bs_d:  0.6037735849056604
# Score oqat_d_w:  0.4811320754716981
# Score oqat_d_wn:  0.4811320754716981
# Score oqat_d_d:  0.49056603773584906
# ===== train size 0.25 ====
# (33, 4) (33,) (99, 4) (99,)
# Distribution of training data
# 1    15
# 0    11
# 2     7
# dtype: int64
# Score decision tree:  0.6767676767676768
# Score oqat_bs_w:  0.6363636363636364
# Score oqat_bs_wn:  0.5959595959595959
# Score oqat_bs_d:  0.6262626262626263
# Score oqat_d_w:  0.5353535353535354
# Score oqat_d_wn:  0.494949494949495
# Score oqat_d_d:  0.5252525252525253
# ===== train size 0.3 ====
# (39, 4) (39,) (93, 4) (93,)
# Distribution of training data
# 1    17
# 0    13
# 2     9
# dtype: int64
# Score decision tree:  0.6236559139784946
# Score oqat_bs_w:  0.7419354838709677
# Score oqat_bs_wn:  0.7419354838709677
# Score oqat_bs_d:  0.7419354838709677
# Score oqat_d_w:  0.6129032258064516
# Score oqat_d_wn:  0.6129032258064516
# Score oqat_d_d:  0.6129032258064516
# ===== train size 0.35 ====
# (46, 4) (46,) (86, 4) (86,)
# Distribution of training data
# 0    18
# 1    18
# 2    10
# dtype: int64
# Score decision tree:  0.8023255813953488
# Score oqat_bs_w:  0.7906976744186046
# Score oqat_bs_wn:  0.7906976744186046
# Score oqat_bs_d:  0.8023255813953488
# Score oqat_d_w:  0.6627906976744186
# Score oqat_d_wn:  0.6627906976744186
# Score oqat_d_d:  0.6744186046511628
# ===== train size 0.4 ====
# (52, 4) (52,) (80, 4) (80,)
# Distribution of training data
# 1    21
# 0    19
# 2    12
# dtype: int64
# Score decision tree:  0.7875
# Score oqat_bs_w:  0.8
# Score oqat_bs_wn:  0.8
# Score oqat_bs_d:  0.8125
# Score oqat_d_w:  0.6875
# Score oqat_d_wn:  0.6875
# Score oqat_d_d:  0.7
# ===== train size 0.45 ====
# (59, 4) (59,) (73, 4) (73,)
# Distribution of training data
# 1    23
# 0    21
# 2    15
# dtype: int64
# Score decision tree:  0.7808219178082192
# Score oqat_bs_w:  0.726027397260274
# Score oqat_bs_wn:  0.726027397260274
# Score oqat_bs_d:  0.726027397260274
# Score oqat_d_w:  0.7397260273972602
# Score oqat_d_wn:  0.7397260273972602
# Score oqat_d_d:  0.7397260273972602
# ===== train size 0.5 ====
# (66, 4) (66,) (66, 4) (66,)
# Distribution of training data
# 1    26
# 0    22
# 2    18
# dtype: int64
# Score decision tree:  0.7878787878787878
# Score oqat_bs_w:  0.8484848484848485
# Score oqat_bs_wn:  0.8484848484848485
# Score oqat_bs_d:  0.8333333333333334
# Score oqat_d_w:  0.7878787878787878
# Score oqat_d_wn:  0.7878787878787878
# Score oqat_d_d:  0.7727272727272727
# ===== train size 0.55 ====
# (72, 4) (72,) (60, 4) (60,)
# Distribution of training data
# 1    30
# 0    23
# 2    19
# dtype: int64
# Score decision tree:  0.8333333333333334
# Score oqat_bs_w:  0.8
# Score oqat_bs_wn:  0.8
# Score oqat_bs_d:  0.8333333333333334
# Score oqat_d_w:  0.8333333333333334
# Score oqat_d_wn:  0.8333333333333334
# Score oqat_d_d:  0.8666666666666667
# ===== train size 0.6 ====
# (79, 4) (79,) (53, 4) (53,)
# Distribution of training data
# 1    33
# 0    26
# 2    20
# dtype: int64
# Score decision tree:  0.8113207547169812
# Score oqat_bs_w:  0.7735849056603774
# Score oqat_bs_wn:  0.7735849056603774
# Score oqat_bs_d:  0.7924528301886793
# Score oqat_d_w:  0.7924528301886793
# Score oqat_d_wn:  0.7924528301886793
# Score oqat_d_d:  0.8113207547169812
# ===== train size 0.65 ====
# (85, 4) (85,) (47, 4) (47,)
# Distribution of training data
# 1    36
# 0    28
# 2    21
# dtype: int64
# Score decision tree:  0.7659574468085106
# Score oqat_bs_w:  0.851063829787234
# Score oqat_bs_wn:  0.851063829787234
# Score oqat_bs_d:  0.851063829787234
# Score oqat_d_w:  0.7446808510638298
# Score oqat_d_wn:  0.7446808510638298
# Score oqat_d_d:  0.7446808510638298
# ===== train size 0.7 ====
# (92, 4) (92,) (40, 4) (40,)
# Distribution of training data
# 1    40
# 0    30
# 2    22
# dtype: int64
# Score decision tree:  0.8
# Score oqat_bs_w:  0.9
# Score oqat_bs_wn:  0.9
# Score oqat_bs_d:  0.9
# Score oqat_d_w:  0.8
# Score oqat_d_wn:  0.8
# Score oqat_d_d:  0.8
# ===== train size 0.75 ====
# (99, 4) (99,) (33, 4) (33,)
# Distribution of training data
# 1    43
# 0    32
# 2    24
# dtype: int64
# Score decision tree:  0.8484848484848485
# Score oqat_bs_w:  0.7878787878787878
# Score oqat_bs_wn:  0.7878787878787878
# Score oqat_bs_d:  0.7878787878787878
# Score oqat_d_w:  0.7272727272727273
# Score oqat_d_wn:  0.7272727272727273
# Score oqat_d_d:  0.7272727272727273
# ===== train size 0.8 ====
# (105, 4) (105,) (27, 4) (27,)
# Distribution of training data
# 1    44
# 0    35
# 2    26
# dtype: int64
# Score decision tree:  0.8518518518518519
# Score oqat_bs_w:  0.8148148148148148
# Score oqat_bs_wn:  0.8518518518518519
# Score oqat_bs_d:  0.8888888888888888
# Score oqat_d_w:  0.6666666666666666
# Score oqat_d_wn:  0.7037037037037037
# Score oqat_d_d:  0.7407407407407407
# ===== train size 0.85 ====
# (112, 4) (112,) (20, 4) (20,)
# Distribution of training data
# 1    46
# 0    38
# 2    28
# dtype: int64
# Score decision tree:  0.8
# Score oqat_bs_w:  0.75
# Score oqat_bs_wn:  0.75
# Score oqat_bs_d:  0.8
# Score oqat_d_w:  0.75
# Score oqat_d_wn:  0.75
# Score oqat_d_d:  0.8
# ===== train size 0.9 ====
# (118, 4) (118,) (14, 4) (14,)
# Distribution of training data
# 1    48
# 0    41
# 2    29
# dtype: int64
# Score decision tree:  0.7142857142857143
# Score oqat_bs_w:  0.6428571428571429
# Score oqat_bs_wn:  0.6428571428571429
# Score oqat_bs_d:  0.7142857142857143
# Score oqat_d_w:  0.5714285714285714
# Score oqat_d_wn:  0.5714285714285714
# Score oqat_d_d:  0.6428571428571429
# ===== train size 0.15 ====
# (19, 4) (19,) (113, 4) (113,)
# Distribution of training data
# 1    7
# 0    6
# 2    6
# dtype: int64
# Score decision tree:  0.5663716814159292
# Score oqat_bs_w:  0.6017699115044248
# Score oqat_bs_wn:  0.6017699115044248
# Score oqat_bs_d:  0.5752212389380531
# Score oqat_d_w:  0.6017699115044248
# Score oqat_d_wn:  0.6017699115044248
# Score oqat_d_d:  0.5752212389380531
# ===== train size 0.2 ====
# (26, 4) (26,) (106, 4) (106,)
# Distribution of training data
# 0    10
# 1     8
# 2     8
# dtype: int64
# Score decision tree:  0.6886792452830188
# Score oqat_bs_w:  0.6320754716981132
# Score oqat_bs_wn:  0.6132075471698113
# Score oqat_bs_d:  0.6320754716981132
# Score oqat_d_w:  0.5754716981132075
# Score oqat_d_wn:  0.5566037735849056
# Score oqat_d_d:  0.5754716981132075
# ===== train size 0.25 ====
# (33, 4) (33,) (99, 4) (99,)
# Distribution of training data
# 0    13
# 1    11
# 2     9
# dtype: int64
# Score decision tree:  0.7272727272727273
# Score oqat_bs_w:  0.6161616161616161
# Score oqat_bs_wn:  0.6161616161616161
# Score oqat_bs_d:  0.6262626262626263
# Score oqat_d_w:  0.5858585858585859
# Score oqat_d_wn:  0.5858585858585859
# Score oqat_d_d:  0.5959595959595959
# ===== train size 0.3 ====
# (39, 4) (39,) (93, 4) (93,)
# Distribution of training data
# 1    16
# 0    13
# 2    10
# dtype: int64
# Score decision tree:  0.7956989247311828
# Score oqat_bs_w:  0.5591397849462365
# Score oqat_bs_wn:  0.5913978494623656
# Score oqat_bs_d:  0.6021505376344086
# Score oqat_d_w:  0.5053763440860215
# Score oqat_d_wn:  0.5376344086021505
# Score oqat_d_d:  0.5483870967741935
# ===== train size 0.35 ====
# (46, 4) (46,) (86, 4) (86,)
# Distribution of training data
# 1    21
# 0    15
# 2    10
# dtype: int64
# Score decision tree:  0.7790697674418605
# Score oqat_bs_w:  0.7790697674418605
# Score oqat_bs_wn:  0.7790697674418605
# Score oqat_bs_d:  0.7790697674418605
# Score oqat_d_w:  0.6744186046511628
# Score oqat_d_wn:  0.6744186046511628
# Score oqat_d_d:  0.6744186046511628
# ===== train size 0.4 ====
# (52, 4) (52,) (80, 4) (80,)
# Distribution of training data
# 1    23
# 0    18
# 2    11
# dtype: int64
# Score decision tree:  0.775
# Score oqat_bs_w:  0.7125
# Score oqat_bs_wn:  0.7
# Score oqat_bs_d:  0.725
# Score oqat_d_w:  0.6375
# Score oqat_d_wn:  0.625
# Score oqat_d_d:  0.65
# ===== train size 0.45 ====
# (59, 4) (59,) (73, 4) (73,)
# Distribution of training data
# 1    26
# 0    20
# 2    13
# dtype: int64
# Score decision tree:  0.7397260273972602
# Score oqat_bs_w:  0.7534246575342466
# Score oqat_bs_wn:  0.7534246575342466
# Score oqat_bs_d:  0.7534246575342466
# Score oqat_d_w:  0.684931506849315
# Score oqat_d_wn:  0.684931506849315
# Score oqat_d_d:  0.684931506849315
# ===== train size 0.5 ====
# (66, 4) (66,) (66, 4) (66,)
# Distribution of training data
# 1    29
# 0    21
# 2    16
# dtype: int64
# Score decision tree:  0.7575757575757576
# Score oqat_bs_w:  0.696969696969697
# Score oqat_bs_wn:  0.7121212121212122
# Score oqat_bs_d:  0.696969696969697
# Score oqat_d_w:  0.6666666666666666
# Score oqat_d_wn:  0.6818181818181818
# Score oqat_d_d:  0.6666666666666666
# ===== train size 0.55 ====
# (72, 4) (72,) (60, 4) (60,)
# Distribution of training data
# 1    32
# 0    24
# 2    16
# dtype: int64
# Score decision tree:  0.7666666666666667
# Score oqat_bs_w:  0.7833333333333333
# Score oqat_bs_wn:  0.7833333333333333
# Score oqat_bs_d:  0.7833333333333333
# Score oqat_d_w:  0.6833333333333333
# Score oqat_d_wn:  0.6833333333333333
# Score oqat_d_d:  0.6833333333333333
# ===== train size 0.6 ====
# (79, 4) (79,) (53, 4) (53,)
# Distribution of training data
# 1    33
# 0    28
# 2    18
# dtype: int64
# Score decision tree:  0.8113207547169812
# Score oqat_bs_w:  0.8113207547169812
# Score oqat_bs_wn:  0.8113207547169812
# Score oqat_bs_d:  0.8301886792452831
# Score oqat_d_w:  0.7924528301886793
# Score oqat_d_wn:  0.7924528301886793
# Score oqat_d_d:  0.8113207547169812
# ===== train size 0.65 ====
# (85, 4) (85,) (47, 4) (47,)
# Distribution of training data
# 1    34
# 0    30
# 2    21
# dtype: int64
# Score decision tree:  0.7872340425531915
# Score oqat_bs_w:  0.7021276595744681
# Score oqat_bs_wn:  0.7659574468085106
# Score oqat_bs_d:  0.7021276595744681
# Score oqat_d_w:  0.6808510638297872
# Score oqat_d_wn:  0.7446808510638298
# Score oqat_d_d:  0.6808510638297872
# ===== train size 0.7 ====
# (92, 4) (92,) (40, 4) (40,)
# Distribution of training data
# 1    36
# 0    33
# 2    23
# dtype: int64
# Score decision tree:  0.8
# Score oqat_bs_w:  0.75
# Score oqat_bs_wn:  0.75
# Score oqat_bs_d:  0.75
# Score oqat_d_w:  0.775
# Score oqat_d_wn:  0.775
# Score oqat_d_d:  0.775
# ===== train size 0.75 ====
# (99, 4) (99,) (33, 4) (33,)
# Distribution of training data
# 0    38
# 1    38
# 2    23
# dtype: int64
# Score decision tree:  0.8181818181818182
# Score oqat_bs_w:  0.7575757575757576
# Score oqat_bs_wn:  0.7272727272727273
# Score oqat_bs_d:  0.7575757575757576
# Score oqat_d_w:  0.7878787878787878
# Score oqat_d_wn:  0.7575757575757576
# Score oqat_d_d:  0.7878787878787878
# ===== train size 0.8 ====
# (105, 4) (105,) (27, 4) (27,)
# Distribution of training data
# 0    40
# 1    40
# 2    25
# dtype: int64
# Score decision tree:  0.8518518518518519
# Score oqat_bs_w:  0.9259259259259259
# Score oqat_bs_wn:  0.8888888888888888
# Score oqat_bs_d:  0.8888888888888888
# Score oqat_d_w:  0.8148148148148148
# Score oqat_d_wn:  0.7777777777777778
# Score oqat_d_d:  0.7777777777777778
# ===== train size 0.85 ====
# (112, 4) (112,) (20, 4) (20,)
# Distribution of training data
# 1    44
# 0    42
# 2    26
# dtype: int64
# Score decision tree:  0.95
# Score oqat_bs_w:  0.85
# Score oqat_bs_wn:  0.85
# Score oqat_bs_d:  0.85
# Score oqat_d_w:  0.9
# Score oqat_d_wn:  0.9
# Score oqat_d_d:  0.9
# ===== train size 0.9 ====
# (118, 4) (118,) (14, 4) (14,)
# Distribution of training data
# 0    46
# 1    45
# 2    27
# dtype: int64
# Score decision tree:  1.0
# Score oqat_bs_w:  0.8571428571428571
# Score oqat_bs_wn:  0.8571428571428571
# Score oqat_bs_d:  0.8571428571428571
# Score oqat_d_w:  0.8571428571428571
# Score oqat_d_wn:  0.8571428571428571
# Score oqat_d_d:  0.8571428571428571
# ===== train size 0.15 ====
# (19, 4) (19,) (113, 4) (113,)
# Distribution of training data
# 1    9
# 0    8
# 2    2
# dtype: int64
# Score decision tree:  0.7876106194690266
# Score oqat_bs_w:  0.7079646017699115
# Score oqat_bs_wn:  0.7079646017699115
# Score oqat_bs_d:  0.6991150442477876
# Score oqat_d_w:  0.5752212389380531
# Score oqat_d_wn:  0.5752212389380531
# Score oqat_d_d:  0.5663716814159292
# ===== train size 0.2 ====
# (26, 4) (26,) (106, 4) (106,)
# Distribution of training data
# 1    11
# 0    10
# 2     5
# dtype: int64
# Score decision tree:  0.8207547169811321
# Score oqat_bs_w:  0.5188679245283019
# Score oqat_bs_wn:  0.5188679245283019
# Score oqat_bs_d:  0.5188679245283019
# Score oqat_d_w:  0.5471698113207547
# Score oqat_d_wn:  0.5471698113207547
# Score oqat_d_d:  0.5471698113207547
# ===== train size 0.25 ====
# (33, 4) (33,) (99, 4) (99,)
# Distribution of training data
# 1    12
# 0    12
# 2     9
# dtype: int64
# Score decision tree:  0.7373737373737373
# Score oqat_bs_w:  0.6868686868686869
# Score oqat_bs_wn:  0.6868686868686869
# Score oqat_bs_d:  0.6767676767676768
# Score oqat_d_w:  0.6666666666666666
# Score oqat_d_wn:  0.6666666666666666
# Score oqat_d_d:  0.6565656565656566
# ===== train size 0.3 ====
# (39, 4) (39,) (93, 4) (93,)
# Distribution of training data
# 1    16
# 0    14
# 2     9
# dtype: int64
# Score decision tree:  0.7741935483870968
# Score oqat_bs_w:  0.7311827956989247
# Score oqat_bs_wn:  0.7311827956989247
# Score oqat_bs_d:  0.7096774193548387
# Score oqat_d_w:  0.6881720430107527
# Score oqat_d_wn:  0.6881720430107527
# Score oqat_d_d:  0.6666666666666666
# ===== train size 0.35 ====
# (46, 4) (46,) (86, 4) (86,)
# Distribution of training data
# 1    19
# 0    18
# 2     9
# dtype: int64
# Score decision tree:  0.872093023255814
# Score oqat_bs_w:  0.8255813953488372
# Score oqat_bs_wn:  0.8255813953488372
# Score oqat_bs_d:  0.8255813953488372
# Score oqat_d_w:  0.6744186046511628
# Score oqat_d_wn:  0.6744186046511628
# Score oqat_d_d:  0.6744186046511628
# ===== train size 0.4 ====
# (52, 4) (52,) (80, 4) (80,)
# Distribution of training data
# 1    22
# 0    19
# 2    11
# dtype: int64
# Score decision tree:  0.8625
# Score oqat_bs_w:  0.7625
# Score oqat_bs_wn:  0.7625
# Score oqat_bs_d:  0.7375
# Score oqat_d_w:  0.75
# Score oqat_d_wn:  0.75
# Score oqat_d_d:  0.725
# ===== train size 0.45 ====
# (59, 4) (59,) (73, 4) (73,)
# Distribution of training data
# 1    25
# 0    21
# 2    13
# dtype: int64
# Score decision tree:  0.821917808219178
# Score oqat_bs_w:  0.8082191780821918
# Score oqat_bs_wn:  0.8082191780821918
# Score oqat_bs_d:  0.7808219178082192
# Score oqat_d_w:  0.7671232876712328
# Score oqat_d_wn:  0.7671232876712328
# Score oqat_d_d:  0.7397260273972602
# ===== train size 0.5 ====
# (66, 4) (66,) (66, 4) (66,)
# Distribution of training data
# 1    27
# 0    24
# 2    15
# dtype: int64
# Score decision tree:  0.803030303030303
# Score oqat_bs_w:  0.7121212121212122
# Score oqat_bs_wn:  0.696969696969697
# Score oqat_bs_d:  0.6818181818181818
# Score oqat_d_w:  0.6818181818181818
# Score oqat_d_wn:  0.6666666666666666
# Score oqat_d_d:  0.6515151515151515
# ===== train size 0.55 ====
# (72, 4) (72,) (60, 4) (60,)
# Distribution of training data
# 1    31
# 0    24
# 2    17
# dtype: int64
# Score decision tree:  0.8166666666666667
# Score oqat_bs_w:  0.6666666666666666
# Score oqat_bs_wn:  0.65
# Score oqat_bs_d:  0.6666666666666666
# Score oqat_d_w:  0.6833333333333333
# Score oqat_d_wn:  0.6666666666666666
# Score oqat_d_d:  0.6833333333333333
# ===== train size 0.6 ====
# (79, 4) (79,) (53, 4) (53,)
# Distribution of training data
# 1    35
# 0    25
# 2    19
# dtype: int64
# Score decision tree:  0.7924528301886793
# Score oqat_bs_w:  0.8301886792452831
# Score oqat_bs_wn:  0.8301886792452831
# Score oqat_bs_d:  0.8301886792452831
# Score oqat_d_w:  0.8490566037735849
# Score oqat_d_wn:  0.8490566037735849
# Score oqat_d_d:  0.8490566037735849
# ===== train size 0.65 ====
# (85, 4) (85,) (47, 4) (47,)
# Distribution of training data
# 1    37
# 0    27
# 2    21
# dtype: int64
# Score decision tree:  0.8085106382978723
# Score oqat_bs_w:  0.7659574468085106
# Score oqat_bs_wn:  0.7659574468085106
# Score oqat_bs_d:  0.7872340425531915
# Score oqat_d_w:  0.7659574468085106
# Score oqat_d_wn:  0.7659574468085106
# Score oqat_d_d:  0.7872340425531915
# ===== train size 0.7 ====
# (92, 4) (92,) (40, 4) (40,)
# Distribution of training data
# 1    38
# 0    32
# 2    22
# dtype: int64
# Score decision tree:  0.775
# Score oqat_bs_w:  0.775
# Score oqat_bs_wn:  0.75
# Score oqat_bs_d:  0.775
# Score oqat_d_w:  0.8
# Score oqat_d_wn:  0.775
# Score oqat_d_d:  0.8
# ===== train size 0.75 ====
# (99, 4) (99,) (33, 4) (33,)
# Distribution of training data
# 1    42
# 0    33
# 2    24
# dtype: int64
# Score decision tree:  0.7878787878787878
# Score oqat_bs_w:  0.7575757575757576
# Score oqat_bs_wn:  0.7575757575757576
# Score oqat_bs_d:  0.7575757575757576
# Score oqat_d_w:  0.7272727272727273
# Score oqat_d_wn:  0.7272727272727273
# Score oqat_d_d:  0.7272727272727273
# ===== train size 0.8 ====
# (105, 4) (105,) (27, 4) (27,)
# Distribution of training data
# 1    43
# 0    37
# 2    25
# dtype: int64
# Score decision tree:  0.7777777777777778
# Score oqat_bs_w:  0.8518518518518519
# Score oqat_bs_wn:  0.8148148148148148
# Score oqat_bs_d:  0.8148148148148148
# Score oqat_d_w:  0.8148148148148148
# Score oqat_d_wn:  0.7777777777777778
# Score oqat_d_d:  0.7777777777777778
# ===== train size 0.85 ====
# (112, 4) (112,) (20, 4) (20,)
# Distribution of training data
# 1    45
# 0    40
# 2    27
# dtype: int64
# Score decision tree:  0.8
# Score oqat_bs_w:  0.95
# Score oqat_bs_wn:  0.9
# Score oqat_bs_d:  0.85
# Score oqat_d_w:  0.95
# Score oqat_d_wn:  0.9
# Score oqat_d_d:  0.85
# ===== train size 0.9 ====
# (118, 4) (118,) (14, 4) (14,)
# Distribution of training data
# 1    47
# 0    43
# 2    28
# dtype: int64
# Score decision tree:  0.7142857142857143
# Score oqat_bs_w:  0.9285714285714286
# Score oqat_bs_wn:  0.8571428571428571
# Score oqat_bs_d:  0.9285714285714286
# Score oqat_d_w:  0.9285714285714286
# Score oqat_d_wn:  0.8571428571428571
# Score oqat_d_d:  0.9285714285714286
# ===== train size 0.15 ====
# (19, 4) (19,) (113, 4) (113,)
# Distribution of training data
# 1    11
# 0     5
# 2     3
# dtype: int64
# Score decision tree:  0.6371681415929203
# Score oqat_bs_w:  0.4336283185840708
# Score oqat_bs_wn:  0.46017699115044247
# Score oqat_bs_d:  0.46017699115044247
# Score oqat_d_w:  0.5486725663716814
# Score oqat_d_wn:  0.5752212389380531
# Score oqat_d_d:  0.5752212389380531
# ===== train size 0.2 ====
# (26, 4) (26,) (106, 4) (106,)
# Distribution of training data
# 1    15
# 0     8
# 2     3
# dtype: int64
# Score decision tree:  0.6981132075471698
# Score oqat_bs_w:  0.5
# Score oqat_bs_wn:  0.5
# Score oqat_bs_d:  0.5
# Score oqat_d_w:  0.5188679245283019
# Score oqat_d_wn:  0.5188679245283019
# Score oqat_d_d:  0.5188679245283019
# ===== train size 0.25 ====
# (33, 4) (33,) (99, 4) (99,)
# Distribution of training data
# 1    16
# 0    12
# 2     5
# dtype: int64
# Score decision tree:  0.7878787878787878
# Score oqat_bs_w:  0.7777777777777778
# Score oqat_bs_wn:  0.7777777777777778
# Score oqat_bs_d:  0.7373737373737373
# Score oqat_d_w:  0.7070707070707071
# Score oqat_d_wn:  0.7070707070707071
# Score oqat_d_d:  0.6666666666666666
# ===== train size 0.3 ====
# (39, 4) (39,) (93, 4) (93,)
# Distribution of training data
# 1    19
# 0    14
# 2     6
# dtype: int64
# Score decision tree:  0.7741935483870968
# Score oqat_bs_w:  0.7419354838709677
# Score oqat_bs_wn:  0.7419354838709677
# Score oqat_bs_d:  0.7311827956989247
# Score oqat_d_w:  0.6989247311827957
# Score oqat_d_wn:  0.6989247311827957
# Score oqat_d_d:  0.6881720430107527
# ===== train size 0.35 ====
# (46, 4) (46,) (86, 4) (86,)
# Distribution of training data
# 1    22
# 0    17
# 2     7
# dtype: int64
# Score decision tree:  0.7558139534883721
# Score oqat_bs_w:  0.7790697674418605
# Score oqat_bs_wn:  0.7674418604651163
# Score oqat_bs_d:  0.7441860465116279
# Score oqat_d_w:  0.7790697674418605
# Score oqat_d_wn:  0.7674418604651163
# Score oqat_d_d:  0.7441860465116279
# ===== train size 0.4 ====
# (52, 4) (52,) (80, 4) (80,)
# Distribution of training data
# 0    22
# 1    22
# 2     8
# dtype: int64
# Score decision tree:  0.8125
# Score oqat_bs_w:  0.8125
# Score oqat_bs_wn:  0.8125
# Score oqat_bs_d:  0.825
# Score oqat_d_w:  0.8
# Score oqat_d_wn:  0.8
# Score oqat_d_d:  0.8125
# ===== train size 0.45 ====
# (59, 4) (59,) (73, 4) (73,)
# Distribution of training data
# 0    25
# 1    24
# 2    10
# dtype: int64
# Score decision tree:  0.7945205479452054
# Score oqat_bs_w:  0.821917808219178
# Score oqat_bs_wn:  0.821917808219178
# Score oqat_bs_d:  0.821917808219178
# Score oqat_d_w:  0.7808219178082192
# Score oqat_d_wn:  0.7808219178082192
# Score oqat_d_d:  0.7808219178082192
# ===== train size 0.5 ====
# (66, 4) (66,) (66, 4) (66,)
# Distribution of training data
# 1    28
# 0    26
# 2    12
# dtype: int64
# Score decision tree:  0.7878787878787878
# Score oqat_bs_w:  0.8333333333333334
# Score oqat_bs_wn:  0.8333333333333334
# Score oqat_bs_d:  0.8181818181818182
# Score oqat_d_w:  0.7727272727272727
# Score oqat_d_wn:  0.7727272727272727
# Score oqat_d_d:  0.7575757575757576
# ===== train size 0.55 ====
# (72, 4) (72,) (60, 4) (60,)
# Distribution of training data
# 1    31
# 0    29
# 2    12
# dtype: int64
# Score decision tree:  0.75
# Score oqat_bs_w:  0.85
# Score oqat_bs_wn:  0.85
# Score oqat_bs_d:  0.85
# Score oqat_d_w:  0.7833333333333333
# Score oqat_d_wn:  0.7833333333333333
# Score oqat_d_d:  0.7833333333333333
# ===== train size 0.6 ====
# (79, 4) (79,) (53, 4) (53,)
# Distribution of training data
# 0    34
# 1    31
# 2    14
# dtype: int64
# Score decision tree:  0.7358490566037735
# Score oqat_bs_w:  0.7924528301886793
# Score oqat_bs_wn:  0.7735849056603774
# Score oqat_bs_d:  0.7924528301886793
# Score oqat_d_w:  0.7547169811320755
# Score oqat_d_wn:  0.7358490566037735
# Score oqat_d_d:  0.7547169811320755
# ===== train size 0.65 ====
# (85, 4) (85,) (47, 4) (47,)
# Distribution of training data
# 0    36
# 1    32
# 2    17
# dtype: int64
# Score decision tree:  0.7021276595744681
# Score oqat_bs_w:  0.8297872340425532
# Score oqat_bs_wn:  0.8297872340425532
# Score oqat_bs_d:  0.8297872340425532
# Score oqat_d_w:  0.8085106382978723
# Score oqat_d_wn:  0.8085106382978723
# Score oqat_d_d:  0.8085106382978723
# ===== train size 0.7 ====
# (92, 4) (92,) (40, 4) (40,)
# Distribution of training data
# 0    38
# 1    36
# 2    18
# dtype: int64
# Score decision tree:  0.675
# Score oqat_bs_w:  0.825
# Score oqat_bs_wn:  0.825
# Score oqat_bs_d:  0.825
# Score oqat_d_w:  0.8
# Score oqat_d_wn:  0.8
# Score oqat_d_d:  0.8
# ===== train size 0.75 ====
# (99, 4) (99,) (33, 4) (33,)
# Distribution of training data
# 1    40
# 0    40
# 2    19
# dtype: int64
# Score decision tree:  0.7878787878787878
# Score oqat_bs_w:  0.8181818181818182
# Score oqat_bs_wn:  0.8181818181818182
# Score oqat_bs_d:  0.8484848484848485
# Score oqat_d_w:  0.7272727272727273
# Score oqat_d_wn:  0.7272727272727273
# Score oqat_d_d:  0.7575757575757576
# ===== train size 0.8 ====
# (105, 4) (105,) (27, 4) (27,)
# Distribution of training data
# 0    42
# 1    42
# 2    21
# dtype: int64
# Score decision tree:  0.7777777777777778
# Score oqat_bs_w:  0.8518518518518519
# Score oqat_bs_wn:  0.8518518518518519
# Score oqat_bs_d:  0.8518518518518519
# Score oqat_d_w:  0.7777777777777778
# Score oqat_d_wn:  0.7777777777777778
# Score oqat_d_d:  0.7777777777777778
# ===== train size 0.85 ====
# (112, 4) (112,) (20, 4) (20,)
# Distribution of training data
# 0    44
# 1    43
# 2    25
# dtype: int64
# Score decision tree:  0.7
# Score oqat_bs_w:  0.75
# Score oqat_bs_wn:  0.75
# Score oqat_bs_d:  0.8
# Score oqat_d_w:  0.7
# Score oqat_d_wn:  0.7
# Score oqat_d_d:  0.75
# ===== train size 0.9 ====
# (118, 4) (118,) (14, 4) (14,)
# Distribution of training data
# 0    47
# 1    45
# 2    26
# dtype: int64
# Score decision tree:  0.8571428571428571
# Score oqat_bs_w:  0.9285714285714286
# Score oqat_bs_wn:  0.9285714285714286
# Score oqat_bs_d:  0.9285714285714286
# Score oqat_d_w:  0.9285714285714286
# Score oqat_d_wn:  0.9285714285714286
# Score oqat_d_d:  0.9285714285714286
# ===== train size 0.15 ====
# (19, 4) (19,) (113, 4) (113,)
# Distribution of training data
# 1    11
# 0     5
# 2     3
# dtype: int64
# Score decision tree:  0.5929203539823009
# Score oqat_bs_w:  0.672566371681416
# Score oqat_bs_wn:  0.6548672566371682
# Score oqat_bs_d:  0.672566371681416
# Score oqat_d_w:  0.5398230088495575
# Score oqat_d_wn:  0.5221238938053098
# Score oqat_d_d:  0.5398230088495575
# ===== train size 0.2 ====
# (26, 4) (26,) (106, 4) (106,)
# Distribution of training data
# 1    13
# 0     8
# 2     5
# dtype: int64
# Score decision tree:  0.5943396226415094
# Score oqat_bs_w:  0.6415094339622641
# Score oqat_bs_wn:  0.6415094339622641
# Score oqat_bs_d:  0.6415094339622641
# Score oqat_d_w:  0.5377358490566038
# Score oqat_d_wn:  0.5377358490566038
# Score oqat_d_d:  0.5377358490566038
# ===== train size 0.25 ====
# (33, 4) (33,) (99, 4) (99,)
# Distribution of training data
# 1    16
# 0    11
# 2     6
# dtype: int64
# Score decision tree:  0.7474747474747475
# Score oqat_bs_w:  0.7171717171717171
# Score oqat_bs_wn:  0.7171717171717171
# Score oqat_bs_d:  0.7171717171717171
# Score oqat_d_w:  0.6262626262626263
# Score oqat_d_wn:  0.6262626262626263
# Score oqat_d_d:  0.6262626262626263
# ===== train size 0.3 ====
# (39, 4) (39,) (93, 4) (93,)
# Distribution of training data
# 1    19
# 0    12
# 2     8
# dtype: int64
# Score decision tree:  0.7741935483870968
# Score oqat_bs_w:  0.6774193548387096
# Score oqat_bs_wn:  0.6774193548387096
# Score oqat_bs_d:  0.6451612903225806
# Score oqat_d_w:  0.6129032258064516
# Score oqat_d_wn:  0.6129032258064516
# Score oqat_d_d:  0.5806451612903226
# ===== train size 0.35 ====
# (46, 4) (46,) (86, 4) (86,)
# Distribution of training data
# 1    20
# 0    16
# 2    10
# dtype: int64
# Score decision tree:  0.7906976744186046
# Score oqat_bs_w:  0.6511627906976745
# Score oqat_bs_wn:  0.6511627906976745
# Score oqat_bs_d:  0.6627906976744186
# Score oqat_d_w:  0.5930232558139535
# Score oqat_d_wn:  0.5930232558139535
# Score oqat_d_d:  0.6046511627906976
# ===== train size 0.4 ====
# (52, 4) (52,) (80, 4) (80,)
# Distribution of training data
# 1    24
# 0    18
# 2    10
# dtype: int64
# Score decision tree:  0.775
# Score oqat_bs_w:  0.6875
# Score oqat_bs_wn:  0.7
# Score oqat_bs_d:  0.7
# Score oqat_d_w:  0.6
# Score oqat_d_wn:  0.6125
# Score oqat_d_d:  0.6125
# ===== train size 0.45 ====
# (59, 4) (59,) (73, 4) (73,)
# Distribution of training data
# 1    27
# 0    20
# 2    12
# dtype: int64
# Score decision tree:  0.7671232876712328
# Score oqat_bs_w:  0.6986301369863014
# Score oqat_bs_wn:  0.6986301369863014
# Score oqat_bs_d:  0.7123287671232876
# Score oqat_d_w:  0.6027397260273972
# Score oqat_d_wn:  0.6027397260273972
# Score oqat_d_d:  0.6164383561643836
# ===== train size 0.5 ====
# (66, 4) (66,) (66, 4) (66,)
# Distribution of training data
# 1    31
# 0    22
# 2    13
# dtype: int64
# Score decision tree:  0.7575757575757576
# Score oqat_bs_w:  0.696969696969697
# Score oqat_bs_wn:  0.696969696969697
# Score oqat_bs_d:  0.696969696969697
# Score oqat_d_w:  0.6818181818181818
# Score oqat_d_wn:  0.6818181818181818
# Score oqat_d_d:  0.6818181818181818
# ===== train size 0.55 ====
# (72, 4) (72,) (60, 4) (60,)
# Distribution of training data
# 1    32
# 0    26
# 2    14
# dtype: int64
# Score decision tree:  0.7333333333333333
# Score oqat_bs_w:  0.7333333333333333
# Score oqat_bs_wn:  0.7333333333333333
# Score oqat_bs_d:  0.7333333333333333
# Score oqat_d_w:  0.5666666666666667
# Score oqat_d_wn:  0.5666666666666667
# Score oqat_d_d:  0.5666666666666667
# ===== train size 0.6 ====
# (79, 4) (79,) (53, 4) (53,)
# Distribution of training data
# 1    34
# 0    31
# 2    14
# dtype: int64
# Score decision tree:  0.7169811320754716
# Score oqat_bs_w:  0.7735849056603774
# Score oqat_bs_wn:  0.7547169811320755
# Score oqat_bs_d:  0.7735849056603774
# Score oqat_d_w:  0.6981132075471698
# Score oqat_d_wn:  0.6792452830188679
# Score oqat_d_d:  0.6981132075471698
# ===== train size 0.65 ====
# (85, 4) (85,) (47, 4) (47,)
# Distribution of training data
# 1    36
# 0    33
# 2    16
# dtype: int64
# Score decision tree:  0.7659574468085106
# Score oqat_bs_w:  0.7446808510638298
# Score oqat_bs_wn:  0.7446808510638298
# Score oqat_bs_d:  0.723404255319149
# Score oqat_d_w:  0.6595744680851063
# Score oqat_d_wn:  0.6595744680851063
# Score oqat_d_d:  0.6382978723404256
# ===== train size 0.7 ====
# (92, 4) (92,) (40, 4) (40,)
# Distribution of training data
# 1    39
# 0    37
# 2    16
# dtype: int64
# Score decision tree:  0.775
# Score oqat_bs_w:  0.85
# Score oqat_bs_wn:  0.85
# Score oqat_bs_d:  0.85
# Score oqat_d_w:  0.85
# Score oqat_d_wn:  0.85
# Score oqat_d_d:  0.85
# ===== train size 0.75 ====
# (99, 4) (99,) (33, 4) (33,)
# Distribution of training data
# 1    42
# 0    38
# 2    19
# dtype: int64
# Score decision tree:  0.8181818181818182
# Score oqat_bs_w:  0.8484848484848485
# Score oqat_bs_wn:  0.8484848484848485
# Score oqat_bs_d:  0.8484848484848485
# Score oqat_d_w:  0.7575757575757576
# Score oqat_d_wn:  0.7575757575757576
# Score oqat_d_d:  0.7575757575757576
# ===== train size 0.8 ====
# (105, 4) (105,) (27, 4) (27,)
# Distribution of training data
# 1    43
# 0    41
# 2    21
# dtype: int64
# Score decision tree:  0.7777777777777778
# Score oqat_bs_w:  0.7407407407407407
# Score oqat_bs_wn:  0.7407407407407407
# Score oqat_bs_d:  0.7407407407407407
# Score oqat_d_w:  0.7037037037037037
# Score oqat_d_wn:  0.7037037037037037
# Score oqat_d_d:  0.7037037037037037
# ===== train size 0.85 ====
# (112, 4) (112,) (20, 4) (20,)
# Distribution of training data
# 0    45
# 1    44
# 2    23
# dtype: int64
# Score decision tree:  0.7
# Score oqat_bs_w:  0.8
# Score oqat_bs_wn:  0.75
# Score oqat_bs_d:  0.75
# Score oqat_d_w:  0.75
# Score oqat_d_wn:  0.7
# Score oqat_d_d:  0.7
# ===== train size 0.9 ====
# (118, 4) (118,) (14, 4) (14,)
# Distribution of training data
# 0    47
# 1    46
# 2    25
# dtype: int64
# Score decision tree:  0.6428571428571429
# Score oqat_bs_w:  0.7142857142857143
# Score oqat_bs_wn:  0.7142857142857143
# Score oqat_bs_d:  0.7142857142857143
# Score oqat_d_w:  0.6428571428571429
# Score oqat_d_wn:  0.6428571428571429
# Score oqat_d_d:  0.6428571428571429

# %%
# compute mean and std
decision_tree_mean = np.mean(decision_tree_runs, axis=0)
decision_tree_std = np.std(decision_tree_runs, axis=0)
oqat_mean_bs_w = np.mean(oqat_runs_bs_w, axis=0)
oqat_std_bs_w = np.std(oqat_runs_bs_w, axis=0)
oqat_mean_bs_wn = np.mean(oqat_runs_bs_wn, axis=0)
oqat_std_bs_wn = np.std(oqat_runs_bs_wn, axis=0)
oqat_mean_bs_d = np.mean(oqat_runs_bs_d, axis=0)
oqat_std_bs_d = np.std(oqat_runs_bs_d, axis=0)
oqat_mean_d_w = np.mean(oqat_runs_d_w, axis=0)
oqat_std_d_w = np.std(oqat_runs_d_w, axis=0)
oqat_mean_d_wn = np.mean(oqat_runs_d_wn, axis=0)
oqat_std_d_wn = np.std(oqat_runs_d_wn, axis=0)
oqat_mean_d_d = np.mean(oqat_runs_d_d, axis=0)
oqat_std_d_d = np.std(oqat_runs_d_d, axis=0)

# plot means and atd for every model at every training size
plt.figure(figsize=(10, 5))
plt.title("Decision tree vs OQAT")
plt.plot(training_sizes, decision_tree_mean, label="Decision tree", color="blue")
# plt.fill_between(training_sizes, decision_tree_mean - decision_tree_std, decision_tree_mean + decision_tree_std, alpha=0.2, color="blue")
plt.plot(training_sizes, oqat_mean_bs_w, label="OQAT bs w", color="red")
# plt.fill_between(training_sizes, oqat_mean_bs_w - oqat_std_bs_w, oqat_mean_bs_w + oqat_std_bs_w, alpha=0.2, color="red")
plt.plot(training_sizes, oqat_mean_bs_wn, label="OQAT bs wn", color="orange")
# plt.fill_between(training_sizes, oqat_mean_bs_wn - oqat_std_bs_wn, oqat_mean_bs_wn + oqat_std_bs_wn, alpha=0.2, color="orange")
plt.plot(training_sizes, oqat_mean_bs_d, label="OQAT bs d", color="green")
# plt.fill_between(training_sizes, oqat_mean_bs_d - oqat_std_bs_d, oqat_mean_bs_d + oqat_std_bs_d, alpha=0.2, color="green")
plt.plot(training_sizes, oqat_mean_d_w, label="OQAT d w", color="purple")
# plt.fill_between(training_sizes, oqat_mean_d_w - oqat_std_d_w, oqat_mean_d_w + oqat_std_d_w, alpha=0.2, color="purple")
plt.plot(training_sizes, oqat_mean_d_wn, label="OQAT d wn", color="brown")
# plt.fill_between(training_sizes, oqat_mean_d_wn - oqat_std_d_wn, oqat_mean_d_wn + oqat_std_d_wn, alpha=0.2, color="brown")
plt.plot(training_sizes, oqat_mean_d_d, label="OQAT d d", color="black")
# plt.fill_between(training_sizes, oqat_mean_d_d - oqat_std_d_d, oqat_mean_d_d + oqat_std_d_d, alpha=0.2, color="black")

plt.xlabel("Training size")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
